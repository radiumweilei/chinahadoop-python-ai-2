# %% [markdown]
# # Pandas及Seaborn绘图

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# ## 1. Pandas绘图

# %%
# 可用的绘图样式 
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  '_classic_test']

# %%
# 设置绘图样式
plt.style.use('seaborn-colorblind')

# %% [markdown]
# ### [DataFrame绘图](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html)

# %%
np.random.seed(100)
df = pd.DataFrame({'A': np.random.randn(365).cumsum(0),
                  'B': np.random.randn(365).cumsum(0) + 20,
                  'C': np.random.randn(365).cumsum(0) - 20},
                 index=pd.date_range('2017/1/1', periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.749765  21.091816 -19.638975
# 2017-01-02 -1.407085  20.686733 -17.061997
# 2017-01-03 -0.254049  21.223177 -15.474676
# 2017-01-04 -0.506485  19.091862 -14.786998
# 2017-01-05  0.474835  19.354939 -14.805210

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df.plot('A', 'B', kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# 颜色(c)和大小(s)有'B'列的数据决定
ax = df.plot('A', 'C', kind='scatter',
        c='B', s=df['B'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# 设置坐标为相同比例
ax.set_aspect('equal')

# %%
df.plot(kind='box')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df.plot(kind='hist', alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df.plot(kind='kde')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### pandas.tools.plotting

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# 用于查看变量间的关系
pd.plotting.scatter_matrix(iris)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4F96A630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FCCA860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4CFB36D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FD7A7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FDD2BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FDD2C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FEB6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FEF35F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FF7BC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E4FF8DBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E5004AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E500AE198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017E501188D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E50178B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E501F5828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E5025B198>]], dtype=object)

# %%
# 用于查看多遍量分布
plt.figure()
pd.plotting.parallel_coordinates(iris, 'Name')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## 2. Seaborn绘图

# %%
import seaborn as sns

# %%
np.random.seed(100)
v1 = pd.Series(np.random.normal(0, 10, 1000), name='v1')
v2 = pd.Series(2 * v1 + np.random.normal(60, 15, 1000), name='v2')

# %%
# 通过matplotlib绘图
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50, 150, 5), label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1111.1111405455044">

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True)
v3 = np.concatenate((v1, v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">

# %%
# 使用seaborn绘图
plt.figure()
sns.distplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">

# %%
# 使用seaborn绘图
plt.figure()
sns.jointplot(v1, v2, alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="600">

# %%
# 使用seaborn绘图
plt.figure()
grid = sns.jointplot(v1, v2, alpha=0.4)
grid.ax_joint.set_aspect('equal')

# %%
plt.figure()
sns.jointplot(v1, v2, kind='hex')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
plt.figure()
sns.jointplot(v1, v2, kind='kde')
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">
# <img src="data:image/png;base64,..." width="598.8889047540268">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde')
# Out:
# <img src="data:image/png;base64,..." width="1102.7272488263034">

# %%
plt.figure()
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris)
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris)
